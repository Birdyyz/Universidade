# %%
n = 
phi_n = 

s = n - phi_n +1

d = s*s - 4*n
p = (s- sqrt(d)) // 2
print(p)
# Out:
# 1519241473884387184801176680536185046873532524996973746500197

# %%
n = 6624109870617439340722165576038951394339973081298855352461951179068139153881423
e = 6583207999594739065079155202158153730666247432439186911652643344323425183584061

p= 309398509797311703696454096146607758709
q = n // p

phi_n = (p-1)*(q-1)

d = pow(e,-1,phi_n)
d
# Out:
# 3471010586904033141231690767290164631623947471252158945647710280095119856113757

# %%
n = 13^2 *29^6 *37^7
res = euler_phi(n)
res
# Out:
# 8275332724086450754368

# %%
n = 112521818540730818289197365527684255830111235756681073213169626775535533349217758784438311235403360306512849695285715522714213937438085596045221263776278979
e = 65537
mens = 1234

d = pow(mens,e,n)
d
# Out:
# 36116725348452216014712859670541132449742566383131537472723618398866080807083104307644759620460827764777180337562672903753742150579027602791601096818062020

# %%
n = 2^30 -1
m = 2^29 -1
a_1, a_2 = 117348712, 517500351 
b_1, b_2 = 640139934, 131820677

s1 = (a_1 + b_1) % n
s2 = (a_2 + b_2) % m

x = crt([s1,s2],[n,m])
x
# Out:
# 460316656109411785
