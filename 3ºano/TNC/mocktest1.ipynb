# %%
factor(45)
# Out:
# 3^2 * 5

# %%
n = 
phi = 

S = n - phi + 1
D = S^2 - 4* n
p = (S - sqrt(D))//2
q = (S + sqrt(D)) // 2
p,q
# Out:
# (1308085822230211232760292468969327072241381503462681853055707,
#  )

# %%
n = 5^1 * 19^5 * 41^6

phi_n = euler_phi(n)

print("phi(n) =", phi_n)
# Out:
# phi(n) = 43483668395100480

# %%
# Dados
n = 3413012929608118436685695145488841338582120418326238568376639927463096918313637640603768706581706697060678683
e = 12322915598948013219065242126291289958062194482130013137641306291885237624328146349993077733921363867938533
p = 210463120035456814669963654604138779537

q = n // p

phi_n = (p - 1)*(q - 1)

d = inverse_mod(e, phi_n)
d_pow = pow(e,-1,phi_n)

print("q =", q)
print("phi(n) =", phi_n)
print("d =", d)
print("d_pow =", d_pow)
# Out:
# q = 16216679335710345085244313248941663690182407180349284276084406142478059
# phi(n) = 3413012929608118436685695145488841338565903738990528223291395614214155044160335197966604752341967686779421088
# d = 2267866536025453678416496738182137539742727824274440797728281377840295526759470981580568467553901235145657421
# d_pow = 2267866536025453678416496738182137539742727824274440797728281377840295526759470981580568467553901235145657421

# %%
# Definir n e m
n = 2^30 - 1
m = 2^29 - 1

# Definir os pares
a1, a2 = 491461630, 377404666
b1, b2 = 853868122, 364720484

# Soma módulo n e módulo m
s1 = (a1 + b1) % n
s2 = (a2 + b2) % m

# Resolver sistema de congruências usando CRT
x = crt([s1, s2], [n, m])

print("A imagem recíproca é:", x)
# Out:
# A imagem recíproca é: 505235493737481812

# %%
# Definir parâmetros
n = 306112679691292335187311454543653788139127728314746946323632253771178719551295934058541886753004313084289347801941977332279434685319681837988592701436502521
e = 65537
mens = 1234

# Calcular a cifração
c = pow(mens, e, n)
c_mod = power_mod(mens,e,n)
print("Cifração c =", c)
print("C_mod:",c_mod)
# Out:
# Cifração c = 173305002104399937570835685086847645680225879677564746595639247955019143876884267919950195541327038664436017716668391920309305320558789069599509959939918903
# C_mod: 173305002104399937570835685086847645680225879677564746595639247955019143876884267919950195541327038664436017716668391920309305320558789069599509959939918903
